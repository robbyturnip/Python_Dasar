# %%
import pandas as pd

anime_df = pd.read_csv('dataanime-norm.csv')
anime_df.head(10)
# Out:
#                               Title   Type Episodes            Status  \
# 0  Fullmetal Alchemist: Brotherhood     TV       64   Finished Airing
# 1                    Kimi no Na wa.  Movie        1   Finished Airing
# 2                          Gintama°     TV       51   Finished Airing
# 3                     Steins;Gate 0     TV       23  Currently Airing
# 4                       Steins;Gate     TV       24   Finished Airing
# 5              Ginga Eiyuu Densetsu    OVA      110   Finished Airing
# 6                          Gintama'     TV       51   Finished Airing
# 7            Hunter x Hunter (2011)     TV      148   Finished Airing
# 8        3-gatsu no Lion 2nd Season     TV       22   Finished Airing
# 9               Gintama': Enchousen     TV       13   Finished Airing
#
#   Start airing End airing Starting season             Broadcast time  \
# 0     2009-4-5   2010-7-4          Spring     Sundays at 17:00 (JST)
# ...

# %%
anime_df[anime_df['Starting season'] == 'Fall']
# Out:
#                                                   Title Type Episodes  \
# 7                                Hunter x Hunter (2011)   TV      148
# 8                            3-gatsu no Lion 2nd Season   TV       22
# 9                                   Gintama': Enchousen   TV       13
# 14                                 Clannad: After Story   TV       24
# 16    Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...   TV       10
# 20                              Haikyuu!! Second Season   TV       25
# 22                              Shigatsu wa Kimi no Uso   TV       22
# 25                        Mushishi Zoku Shou 2nd Season   TV       10
# 27                                       Hajime no Ippo   TV       75
# 29                      Code Geass: Hangyaku no Lelouch   TV       25
# 37                                             Mushishi   TV       26
# 41                                        One Punch Man   TV       12
# ...

# %%
anime_df[anime_df['Genres'].str.contains('Action')==True]
# Out:
#                                                   Title     Type Episodes  \
# 0                      Fullmetal Alchemist: Brotherhood       TV       64
# 2                                              Gintama°       TV       51
# 6                                              Gintama'       TV       51
# 7                                Hunter x Hunter (2011)       TV      148
# 9                                   Gintama': Enchousen       TV       13
# 10    Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...    Movie        1
# 13                                             Gintama.       TV       12
# 15                                              Gintama       TV      201
# 17                   Code Geass: Hangyaku no Lelouch R2       TV       25
# 21                     Kizumonogatari III: Reiketsu-hen    Movie        1
# 23                  Gintama.: Shirogane no Tamashii-hen       TV       12
# 26                                         Cowboy Bebop       TV       26
# ...

# %%
from matplotlib import pyplot as plt

anime_trend = anime_df[['Start airing','Members']]
anime_trend = anime_trend.sort_values(by='Start airing',ascending=True)

plt.plot(anime_trend['Start airing'],anime_trend['Members'])
plt.locator_params(axis='x',nbins=10)
plt.xticks(rotation=90)
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Penonton')
plt.title('Trend Jumlah Penonton')
plt.show()

# %%
from matplotlib import pyplot as plt

anime_trend = anime_df[['End airing','Favorites']]
anime_trend = anime_trend.sort_values(by='End airing',ascending=True)

plt.plot(anime_trend['End airing'],anime_trend['Favorites'])
plt.locator_params(axis='x',nbins=10)
plt.xticks(rotation=90)
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Penonton')
plt.title('Trend Jumlah Penonton')
plt.show()

# %%
anime_df[anime_df['Rating'].str.contains('PG-13')==True]
# Out:
#                                                   Title     Type Episodes  \
# 1                                        Kimi no Na wa.    Movie        1
# 3                                         Steins;Gate 0       TV       23
# 4                                           Steins;Gate       TV       24
# 6                                              Gintama'       TV       51
# 7                                Hunter x Hunter (2011)       TV      148
# 8                            3-gatsu no Lion 2nd Season       TV       22
# 9                                   Gintama': Enchousen       TV       13
# 10    Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...    Movie        1
# 11                                       Koe no Katachi    Movie        1
# 13                                             Gintama.       TV       12
# 14                                 Clannad: After Story       TV       24
# 15                                              Gintama       TV      201
# ...

# %%
anime_df[anime_df['Type'].str.contains('Movie')==True]
# Out:
#                                                   Title   Type Episodes  \
# 1                                        Kimi no Na wa.  Movie        1
# 10    Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...  Movie        1
# 11                                       Koe no Katachi  Movie        1
# 19                        Sen to Chihiro no Kamikakushi  Movie        1
# 21                     Kizumonogatari III: Reiketsu-hen  Movie        1
# 28                                        Mononoke Hime  Movie        1
# 34                         Ookami Kodomo no Ame to Yuki  Movie        1
# 40                                  Howl no Ugoku Shiro  Movie        1
# 42                        Suzumiya Haruhi no Shoushitsu  Movie        1
# 44                  Mushishi Zoku Shou: Suzu no Shizuku  Movie        1
# 45                      Kizumonogatari II: Nekketsu-hen  Movie        1
# 61                       Kara no Kyoukai 5: Mujun Rasen  Movie        1
# ...

# %%
from matplotlib import pyplot as plt

anime_trend = anime_df[['Start airing','Members']]
anime_trend = anime_trend.sort_values(by='Start airing',ascending=True)

plt.plot(anime_trend['Start airing'],anime_trend['Members'],'--og')
plt.locator_params(axis='x',nbins=10)
plt.xticks(rotation=90)
plt.xlabel('Tanggal')
plt.ylabel('Jumlah Penonton')
plt.title('Trend Jumlah Penonton')
plt.show()

# %%
#scatter plot
plt.plot(anime_df['Members'],anime_df['Score'],'.')
plt.xlim(0,400000)
plt.ylim(7.5,8.5)
# Out:
# (7.5, 8.5)

# %%
import pandas as pd
from matplotlib import pyplot as plt
anime_df = pd.read_csv('dataanime-norm.csv')
plt.boxplot([anime_df['Members'],anime_df['Score']])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f9235deb5f8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f9235ddf048>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f9235ddfcc0>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f9235ddf898>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f9235deb748>,
# ...
#   <matplotlib.lines.Line2D at 0x7f9235ded978>]}

# %%
#histogram
plt.hist(anime_df['Score'])
# Out:
# (array([436., 361., 271., 189., 135.,  90.,  37.,  24.,  11.,   9.]),
#  array([7.48 , 7.657, 7.834, 8.011, 8.188, 8.365, 8.542, 8.719, 8.896,
#         9.073, 9.25 ]),
#  <a list of 10 Patch objects>)
